# %% [markdown]
# <a href="https://colab.research.google.com/github/Paritoshyadav/understanding-the-global-trends-in-investments-/blob/master/global_trends_in_investments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get update
# !apt-get upgrade
# Out:
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease [3,626 B]
# Hit:4 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Ign:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:7 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:9 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic InRelease
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# ...

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
#@title Most of the analysis is done through tableau

# %%
Dataset=pd.read_csv('rounds2.csv',encoding='ISO-8859-1')

# %%
Dataset.head()
# Out:
#                      company_permalink  ... raised_amount_usd
# 0                  /organization/-fame  ...        10000000.0
# 1               /ORGANIZATION/-QOUNTER  ...               NaN
# 2               /organization/-qounter  ...          700000.0
# 3  /ORGANIZATION/-THE-ONE-OF-THEM-INC-  ...         3406878.0
# 4                /organization/0-6-com  ...         2000000.0
#
# [5 rows x 6 columns]

# %%
Dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114949 entries, 0 to 114948
# Data columns (total 6 columns):
# company_permalink          114949 non-null object
# funding_round_permalink    114949 non-null object
# funding_round_type         114949 non-null object
# funding_round_code         31140 non-null object
# funded_at                  114949 non-null object
# raised_amount_usd          94959 non-null float64
# dtypes: float64(1), object(5)
# memory usage: 5.3+ MB

# %%
Dataset.shape
# Out:
# (114949, 6)

# %%
Com=pd.read_csv('companies.txt',sep="\t",encoding='ISO-8859-1')

# %%
Com.head()
# Out:
#                              permalink  ...  founded_at
# 0                  /Organization/-Fame  ...         NaN
# 1               /Organization/-Qounter  ...  04-09-2014
# 2  /Organization/-The-One-Of-Them-Inc-  ...         NaN
# 3                /Organization/0-6-Com  ...  01-01-2007
# 4       /Organization/004-Technologies  ...  01-01-2010
#
# [5 rows x 10 columns]

# %%
Com.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66368 entries, 0 to 66367
# Data columns (total 10 columns):
# permalink        66368 non-null object
# name             66367 non-null object
# homepage_url     61310 non-null object
# category_list    63220 non-null object
# status           66368 non-null object
# country_code     59410 non-null object
# state_code       57821 non-null object
# region           58338 non-null object
# city             58340 non-null object
# founded_at       51147 non-null object
# dtypes: object(10)
# memory usage: 5.1+ MB

# %%
Com.shape
# Out:
# (66368, 10)

# %%
len(Dataset.company_permalink.unique())
# Out:
# 90247

# %%
Com['permalink']=Com['permalink'].str.lower()

# %%
Com.shape
# Out:
# (66368, 10)

# %%
len(Com.permalink.unique())
# Out:
# 66368

# %%
Dataset['company_permalink']=Dataset['company_permalink'].str.lower()

# %%
len(Dataset.company_permalink.unique())
# Out:
# 66370

# %% [markdown]
# Look like panda cannot encode some different lang company names

# %%
Dataset.loc[~Dataset['company_permalink'].isin(Com['permalink'])]
# Out:
#                                         company_permalink  ... raised_amount_usd
# 29597                             /organization/e-cãbica  ...               NaN
# 31863        /organization/energystone-games-çµç³æ¸¸æ  ...               NaN
# 45176                /organization/huizuche-com-æ ç§ÿè½¦  ...               NaN
# 58473              /organization/magnet-tech-ç£ç³ç§æ  ...         1625585.0
# 101036  /organization/tipcat-interactive-æ²èÿä¿¡æ¯ç...  ...               NaN
# 109969             /organization/weiche-tech-åè½¦ç§æ  ...               NaN
# 113839                 /organization/zengame-ç¦
# æ¸¸ç§æ  ...               NaN
#
# [7 rows x 6 columns]

# %% [markdown]
# U might not find this problem in excel or tableau

# %%
import chardet

# %%
raw=open('rounds2.csv','rb').read()

# %%
result=chardet.detect(raw)
chardet=result['encoding']
print(chardet)
# Out:
# Windows-1254

# %% [markdown]
# This encoding might solve problem

# %%
dataset_encode=pd.read_csv('rounds2.csv',encoding="Windows-1254")

# %% [markdown]
# Not going to work directly

# %%
Dataset['company_permalink']=Dataset.company_permalink.str.encode('utf-8').str.decode('ascii','ignore')

# %%
Dataset.loc[~Dataset['company_permalink'].isin(Com['permalink']),:]
# Out:
#                                         company_permalink  ... raised_amount_usd
# 77                                  /organization/10north  ...               NaN
# 729                               /organization/51wofang-  ...         5000000.0
# 2670                              /organization/adslinked  ...          100000.0
# 3166    /organization/aesthetic-everything-social-network  ...               NaN
# 3291                 /organization/affluent-attach-club-2  ...          100000.0
# 4568                           /organization/allgu-outlet  ...         1400000.0
# 8097                             /organization/asiansbook  ...          100000.0
# 8652                              /organization/atlye-gri  ...           13940.0
# 9784                                  /organization/axgaz  ...         4094392.0
# 14311              /organization/boral-bikes-incorporated  ...               NaN
# 14798                          /organization/brasil-oznio  ...          799686.0
# ...

# %%
len(Dataset.company_permalink.unique())
# Out:
# 66368

# %% [markdown]
# it worked!!!!!!!!!!!!

# %%
Com['permalink']=Com.permalink.str.encode('utf-8').str.decode('ascii','ignore')

# %%
len(Com.permalink.unique())
# Out:
# 66368

# %% [markdown]
# Both permalink same >>>>>>>GREAT

# %%
len(Dataset.loc[~Dataset['company_permalink'].isin(Com['permalink']),:])
# Out:
# 0

# %% [markdown]
# Valdating

# %%
Com.isnull().sum()
# Out:
# permalink            0
# name                 1
# homepage_url      5058
# category_list     3148
# status               0
# country_code      6958
# state_code        8547
# region            8030
# city              8028
# founded_at       15221
# dtype: int64

# %%
Dataset.isnull().sum()
# Out:
# company_permalink              0
# funding_round_permalink        0
# funding_round_type             0
# funding_round_code         83809
# funded_at                      0
# raised_amount_usd          19990
# dtype: int64

# %%
Full=pd.merge(Com,Dataset,left_on='permalink',right_on='company_permalink')

# %%
Full.head()
# Out:
#                              permalink  ... raised_amount_usd
# 0                  /organization/-fame  ...        10000000.0
# 1               /organization/-qounter  ...               NaN
# 2               /organization/-qounter  ...          700000.0
# 3  /organization/-the-one-of-them-inc-  ...         3406878.0
# 4                /organization/0-6-com  ...         2000000.0
#
# [5 rows x 16 columns]

# %%
Full=Full.drop(columns=["company_permalink"])

# %%
Full.isna().sum()
# Out:
# permalink                      0
# name                           1
# homepage_url                6134
# category_list               3410
# status                         0
# country_code                8678
# state_code                 10946
# region                     10167
# city                       10164
# founded_at                 20521
# funding_round_permalink        0
# funding_round_type             0
# funding_round_code         83809
# funded_at                      0
# raised_amount_usd          19990
# dtype: int64

# %%
100*(Full.isna().sum()/len(Full.index))
# Out:
# permalink                   0.000000
# name                        0.000870
# homepage_url                5.336280
# category_list               2.966533
# status                      0.000000
# country_code                7.549435
# state_code                  9.522484
# region                      8.844792
# city                        8.842182
# founded_at                 17.852265
# funding_round_permalink     0.000000
# funding_round_type          0.000000
# funding_round_code         72.909725
# funded_at                   0.000000
# raised_amount_usd          17.390321
# dtype: float64

# %%
Full=Full.drop(columns=["homepage_url","founded_at","funding_round_code","funding_round_permalink"])

# %%
100*(Full.isna().sum()/len(Full.index))
# Out:
# permalink              0.000000
# name                   0.000870
# category_list          2.966533
# status                 0.000000
# country_code           7.549435
# state_code             9.522484
# region                 8.844792
# city                   8.842182
# funding_round_type     0.000000
# funded_at              0.000000
# raised_amount_usd     17.390321
# dtype: float64

# %%
Full=Full.drop(columns=["region","state_code","city"])

# %%
100*(Full.isna().sum()/len(Full.index))
# Out:
# permalink              0.000000
# name                   0.000870
# category_list          2.966533
# status                 0.000000
# country_code           7.549435
# funding_round_type     0.000000
# funded_at              0.000000
# raised_amount_usd     17.390321
# dtype: float64

# %%
Full['raised_amount_usd'].describe()
# Out:
# count    9.495900e+04
# mean     1.042687e+07
# std      1.148212e+08
# min      0.000000e+00
# 25%      3.225000e+05
# 50%      1.680511e+06
# 75%      7.000000e+06
# max      2.127194e+10
# Name: raised_amount_usd, dtype: float64

# %% [markdown]
# Its is messed up

# %%
Full=Full[~np.isnan(Full['raised_amount_usd'])]

# %%
Full=Full[~pd.isnull(Full['country_code'])]

# %%
Full=Full[~pd.isnull(Full['category_list'])]

# %%
Full=Full[~pd.isnull(Full['name'])]

# %%
100*(Full.isna().sum()/len(Full.index))
# Out:
# permalink             0.0
# name                  0.0
# category_list         0.0
# status                0.0
# country_code          0.0
# funding_round_type    0.0
# funded_at             0.0
# raised_amount_usd     0.0
# dtype: float64

# %%
Full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88528 entries, 0 to 114947
# Data columns (total 8 columns):
# permalink             88528 non-null object
# name                  88528 non-null object
# category_list         88528 non-null object
# status                88528 non-null object
# country_code          88528 non-null object
# funding_round_type    88528 non-null object
# funded_at             88528 non-null object
# raised_amount_usd     88528 non-null float64
# dtypes: float64(1), object(7)
# memory usage: 6.1+ MB

# %%
Full.head()
# Out:
#                              permalink  ... raised_amount_usd
# 0                  /organization/-fame  ...        10000000.0
# 2               /organization/-qounter  ...          700000.0
# 4                /organization/0-6-com  ...         2000000.0
# 6     /organization/01games-technology  ...           41250.0
# 7  /organization/0ndine-biomedical-inc  ...           43360.0
#
# [5 rows x 8 columns]

# %%
df=Full

# %%
df.head()
# Out:
#                              permalink  ... raised_amount_usd
# 0                  /organization/-fame  ...        10000000.0
# 2               /organization/-qounter  ...          700000.0
# 4                /organization/0-6-com  ...         2000000.0
# 6     /organization/01games-technology  ...           41250.0
# 7  /organization/0ndine-biomedical-inc  ...           43360.0
#
# [5 rows x 8 columns]

# %%
df=df[(df.funding_round_type=="venture")|(df.funding_round_type=="seed")|(df.funding_round_type=="angel")|(df.funding_round_type=="private_equity")]

# %%
df.pivot_table(values='raised_amount_usd',columns='funding_round_type',aggfunc=[np.median,np.mean])
# Out:
#                       median                 ...           mean
# funding_round_type     angel private_equity  ...           seed       venture
# raised_amount_usd   414906.0     20000000.0  ...  747827.947852  1.172422e+07
#
# [1 rows x 8 columns]

# %%
df.groupby('funding_round_type')['raised_amount_usd'].median().sort_values(ascending=False)
# Out:
# funding_round_type
# private_equity    20000000.0
# venture            5000000.0
# angel               414906.0
# seed                300000.0
# Name: raised_amount_usd, dtype: float64

# %% [markdown]
# If our funding is around 15m(assuming) we cannot go for private equity

# %% [markdown]
# going for venture in that case

# %%
#@title COUNTRY ANALYSIS(Taking only english speaking country)

# %%
df=df[df.funding_round_type=='venture']

# %%
country=df.groupby('country_code')['raised_amount_usd'].sum().sort_values(ascending=False)

# %%
df.head()
# Out:
#                               permalink  ... raised_amount_usd
# 0                   /organization/-fame  ...        10000000.0
# 4                 /organization/0-6-com  ...         2000000.0
# 8   /organization/0ndine-biomedical-inc  ...          719491.0
# 10                 /organization/0xdata  ...        20000000.0
# 11                 /organization/0xdata  ...         1700000.0
#
# [5 rows x 8 columns]

# %%
country
# Out:
# country_code
# USA    4.200680e+11
# CHN    3.933892e+10
# GBR    2.007281e+10
# IND    1.426151e+10
# CAN    9.482218e+09
# FRA    7.226851e+09
# ISR    6.854350e+09
# DEU    6.306922e+09
# JPN    3.167647e+09
# SWE    3.145857e+09
# NLD    2.903876e+09
# CHE    2.801560e+09
# SGP    2.793918e+09
# ESP    1.827622e+09
# BRA    1.785818e+09
# IRL    1.669286e+09
# RUS    1.570426e+09
# AUS    1.319029e+09
# DNK    1.228311e+09
# FIN    1.043200e+09
# BEL    1.030840e+09
# NOR    9.536361e+08
# KOR    8.919883e+08
# MYS    8.830588e+08
# HKG    7.812670e+08
# TWN    6.239795e+08
# AUT    5.833607e+08
# TUR    5.590975e+08
# ITA    4.882894e+08
# NZL    4.483164e+08
#            ...
# KWT    1.400000e+07
# LIE    1.309172e+07
# MNE    1.220000e+07
# SVN    1.201751e+07
# BGR    1.130000e+07
# KAZ    1.100000e+07
# GRC    1.074378e+07
# BAH    8.900000e+06
# TTO    8.500000e+06
# SVK    8.241062e+06
# BGD    7.002000e+06
# LBN    6.455000e+06
# GGY    3.960000e+06
# TUN    3.920000e+06
# ...

# %% [markdown]
# Taking top 9 only

# %%
top_9=country[:9]

# %%
top_9
# Out:
# country_code
# USA    4.200680e+11
# CHN    3.933892e+10
# GBR    2.007281e+10
# IND    1.426151e+10
# CAN    9.482218e+09
# FRA    7.226851e+09
# ISR    6.854350e+09
# DEU    6.306922e+09
# JPN    3.167647e+09
# Name: raised_amount_usd, dtype: float64

# %% [markdown]
# only english speaking country we want

# %%
df=df[(df.country_code=='USA') | (df.country_code=='IND') | (df.country_code=='GBR')]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38803 entries, 0 to 114936
# Data columns (total 8 columns):
# permalink             38803 non-null object
# name                  38803 non-null object
# category_list         38803 non-null object
# status                38803 non-null object
# country_code          38803 non-null object
# funding_round_type    38803 non-null object
# funded_at             38803 non-null object
# raised_amount_usd     38803 non-null float64
# dtypes: float64(1), object(7)
# memory usage: 2.7+ MB

# %%
#@title Its time for sector analysis

# %%
df.loc[:,'main_category']=df['category_list'].apply(lambda x: x.split("|")[0])

# %%
df.head()
# Out:
#                      permalink          name  ... raised_amount_usd main_category
# 0          /organization/-fame         #fame  ...        10000000.0         Media
# 10        /organization/0xdata        H2O.ai  ...        20000000.0     Analytics
# 11        /organization/0xdata        H2O.ai  ...         1700000.0     Analytics
# 12        /organization/0xdata        H2O.ai  ...         8900000.0     Analytics
# 22  /organization/1-mainstream  1 Mainstream  ...         5000000.0          Apps
#
# [5 rows x 9 columns]

# %%
map=pd.read_csv('mapping.csv',sep=",")

# %%
map.head()
# Out:
#    category_list  ...  Social, Finance, Analytics, Advertising
# 0            NaN  ...                                        0
# 1             3D  ...                                        0
# 2    3D Printing  ...                                        0
# 3  3D Technology  ...                                        0
# 4     Accounting  ...                                        1
#
# [5 rows x 10 columns]

# %%
map.isnull().sum()
# Out:
# category_list                              1
# Automotive & Sports                        0
# Blanks                                     0
# Cleantech / Semiconductors                 0
# Entertainment                              0
# Health                                     0
# Manufacturing                              0
# News, Search and Messaging                 0
# Others                                     0
# Social, Finance, Analytics, Advertising    0
# dtype: int64

# %%
map=map[~pd.isnull(map["category_list"])]
map.isnull().sum()
# Out:
# category_list                              0
# Automotive & Sports                        0
# Blanks                                     0
# Cleantech / Semiconductors                 0
# Entertainment                              0
# Health                                     0
# Manufacturing                              0
# News, Search and Messaging                 0
# Others                                     0
# Social, Finance, Analytics, Advertising    0
# dtype: int64

# %%
map['category_list']=map['category_list'].str.lower()

# %%
df['main_category']=df['main_category'].str.lower()

# %%
df[~df['main_category'].isin(map['category_list'])]
# Out:
#                                              permalink  ...        main_category
# 10                                /organization/0xdata  ...            analytics
# 11                                /organization/0xdata  ...            analytics
# 12                                /organization/0xdata  ...            analytics
# 61                               /organization/100plus  ...            analytics
# 198                        /organization/1world-online  ...            analytics
# 199                        /organization/1world-online  ...            analytics
# 200                        /organization/1world-online  ...            analytics
# 256                            /organization/24-7-card  ...              finance
# 822     /organization/6th-wave-innovations-corporation  ...       nanotechnology
# 832                     /organization/7-billion-people  ...            analytics
# 873                           /organization/7park-data  ...            analytics
# ...

# %%
map[~map['category_list'].isin(df['main_category'])]
# Out:
#                 category_list  ...  Social, Finance, Analytics, Advertising
# 16      air pollution control  ...                                        0
# 20        alter0tive medicine  ...                                        0
# 22                   a0lytics  ...                                        1
# 33                aquaculture  ...                                        0
# 49       b2b express delivery  ...                                        1
# 59          big data a0lytics  ...                                        1
# 64   biomass power generation  ...                                        0
# 69           boating industry  ...                                        0
# 77            building owners  ...                                        0
# 79          business a0lytics  ...                                        1
# 85         business travelers  ...                                        0
# ...

# %% [markdown]
# Some mis typing again in database

# %%
map['category_list']=map['category_list'].apply(lambda x:x.replace('0','na'))

# %%
map[~map['category_list'].isin(df['main_category'])]
# Out:
#                 category_list  ...  Social, Finance, Analytics, Advertising
# 16      air pollution control  ...                                        0
# 33                aquaculture  ...                                        0
# 49       b2b express delivery  ...                                        1
# 64   biomass power generation  ...                                        0
# 69           boating industry  ...                                        0
# 77            building owners  ...                                        0
# 85         business travelers  ...                                        0
# 94               casual games  ...                                        0
# 97                  charities  ...                                        1
# 103            china internet  ...                                        0
# 104           civil engineers  ...                                        0
# ...

# %%
join = pd.merge(df,map,how='inner',left_on='main_category',right_on='category_list')

# %%
join.head()
# Out:
#                        permalink  ... Social, Finance, Analytics, Advertising
# 0            /organization/-fame  ...                                       0
# 1            /organization/90min  ...                                       0
# 2            /organization/90min  ...                                       0
# 3            /organization/90min  ...                                       0
# 4  /organization/all-def-digital  ...                                       0
#
# [5 rows x 19 columns]

# %%
join=join.drop(columns=['category_list_x'])
join=join.drop(columns=['category_list_y'])

# %%
join.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38788 entries, 0 to 38787
# Data columns (total 17 columns):
# permalink                                  38788 non-null object
# name                                       38788 non-null object
# status                                     38788 non-null object
# country_code                               38788 non-null object
# funding_round_type                         38788 non-null object
# funded_at                                  38788 non-null object
# raised_amount_usd                          38788 non-null float64
# main_category                              38788 non-null object
# Automotive & Sports                        38788 non-null int64
# Blanks                                     38788 non-null int64
# Cleantech / Semiconductors                 38788 non-null int64
# Entertainment                              38788 non-null int64
# Health                                     38788 non-null int64
# ...

# %%
join.to_csv('for_tableau.csv',index=False)

# %%
#@title Analysis graph on tableau for better visualzation Ty for checking out this project
